# %%
import pandas as pd
import requests 
import os
from xml.etree import ElementTree
from datetime import datetime

# %%
chunk_size = 12 ** 6
TrafficEvents = None

TrafficEvents = {
    "name": "TrafficEvents",
    # "file_name": "TrafficEvents_Aug16_Dec19_Publish_Road_Construction.csv",
    "file_name": "All_Constructions_June2020_Combined_TO_StartEnd_30_100.csv",
    "path": "/home/amin/CETI/RoadConstruction/TrafficEventData/",
    "part_path": "part"
}

number_of_records_in_each_file = 500
number_of_folders = 10
number_of_file_in_folders = 411

# %%
def read_big_data_by_filter_with_key_values(path, filters):
    data = None
    print("method {} is started ".format("read_big_data_filter_with_key_values"))
    print("read csv data is started with file {}".format(path))
    print("chunk size is {}".format(chunk_size))
    for key, value in zip(filters['keys'], filters['values']):
        print("the key is {} and the value is {}".format(filters['keys'], filters['values']))
    for num, df in enumerate(pd.read_csv(path, chunksize=chunk_size), start=1):
        print("continue reading file page num is {}".format(num))
        for key, value in zip(filters['keys'], filters['values']):
            df = df[df[key] == value]
        data = df.append(data)
    print("method {} finished ".format("read_big_data_filter_with_key_values"))
    return data

# %%
traffic_file_path = TrafficEvents["path"] + TrafficEvents["file_name"]

traffic_filters = {
    "keys": ["Type"],
    "values": ["Construction"],
    }

traffic_events_data = read_big_data_by_filter_with_key_values(traffic_file_path, traffic_filters)
# Out:
# method read_big_data_filter_with_key_values is started
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/All_Constructions_June2020_Combined_TO_StartEnd_30_100.csv
# chunk size is 2985984
# the key is ['Type'] and the value is ['Construction']
# /home/amin/python_env/roadConstruction/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3337: DtypeWarning: Columns (12,15,17,37) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# continue reading file page num is 1
# method read_big_data_filter_with_key_values finished

# %%
traffic_events_data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2046493 entries, 0 to 2050890
# Data columns (total 58 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   Id                       object
#  1   Source                   object
#  2   Type                     object
#  3   EventCode                float64
#  4   Severity                 int64
#  5   StartPoint_Lat           float64
#  6   StartPoint_Lng           float64
#  7   EndPoint_Lat             float64
#  8   EndPoint_Lng             float64
#  9   Distance(mi)             float64
#  10  StartTime                object
#  11  EndTime                  object
#  12  ImpactingRoad            object
#  13  DelayFromTypical(mins)   float64
#  14  DelayFromFreeFlow(mins)  float64
#  15  ShortDescription         object
#  16  FullDescription          object
#  17  AdditionalDescription    object
#  18  Number                   float64
#  19  Street                   object
#  20  Side                     object
#  21  City                     object
#  22  County                   object
#  23  State                    object
#  24  Country                  object
#  25  ZipCode                  object
#  26  LocalTimeZone            object
#  27  AirportCode              object
#  28  WeatherTimeStamp         object
#  29  Temperature(F)           float64
#  30  WindChill(F)             float64
#  31  Humidity(%)              float64
#  32  Pressure(in)             float64
#  33  Visibility(mi)           float64
#  34  WindDir                  object
#  35  WindSpeed(mph)           float64
#  36  Precipitation(in)        float64
#  37  Event                    object
#  38  Conditions               object
#  39  DayLight                 object
#  40  AstronomicalDayLight     object
#  41  NauticalDayLight         object
#  42  CivilDayLight            object
#  43  Amenity                  bool
#  44  Bump                     bool
#  45  Crossing                 bool
#  46  Entrance                 bool
#  47  Give_Way                 bool
#  48  Junction                 bool
#  49  Noexit                   bool
#  50  Railway                  bool
#  51  Roundabout               bool
#  52  Station                  bool
#  53  Stop                     bool
#  54  Traffic_Calming          bool
#  55  Traffic_Signal           bool
#  56  Turning_Circle           bool
#  57  Turning_Loop             bool
# dtypes: bool(15), float64(16), int64(1), object(26)
# memory usage: 716.3+ MB

# %%
traffic_events_data.head(10)
# Out:
#      Id Source          Type  EventCode  Severity  StartPoint_Lat  \
# 0   B-1   Bing  Construction        NaN         3       38.250703
# 1   B-3   Bing  Construction        NaN         4       38.559100
# 2   B-4   Bing  Construction        NaN         3       38.252140
# 3   B-5   Bing  Construction        NaN         3       41.092170
# 4   B-6   Bing  Construction        NaN         3       38.252580
# 5   B-7   Bing  Construction        NaN         4       41.738950
# 6   B-9   Bing  Construction        NaN         2       39.500000
# 7  B-10   Bing  Construction        NaN         3       38.255166
# 8  B-13   Bing  Construction        NaN         3       39.094616
# 9  B-14   Bing  Construction        NaN         3       41.679750
#
#    StartPoint_Lng  EndPoint_Lat  EndPoint_Lng  Distance(mi)  ... Junction  \
# 0      -85.750555     38.257121    -85.741728      0.652697  ...    False
# 1      -85.764440     38.575910    -85.785860      1.639514  ...    False
# 2      -85.748500     38.251330    -85.746610      0.116827  ...    False
# 3      -80.645980     41.096203    -80.635086      0.632006  ...    False
# 4      -85.746360     38.250530    -85.746758      0.143278  ...     True
# 5      -84.234150     41.738990    -84.222620      0.594453  ...    False
# 6      -84.730310     39.489353    -84.721373      0.876482  ...    False
# 7      -85.741822     38.256585    -85.739618      0.154635  ...    False
# 8      -84.864515     39.095992    -84.858633      0.329429  ...    False
# 9      -81.303350     41.690332    -81.305615      0.740429  ...    False
#
#   Noexit Railway  Roundabout  Station   Stop Traffic_Calming Traffic_Signal  \
# 0  False   False       False    False  False           False          False
# 1  False   False       False    False  False           False          False
# 2  False   False       False     True  False           False           True
# 3  False   False       False    False  False           False          False
# 4  False   False       False     True  False           False           True
# 5  False   False       False    False  False           False          False
# 6  False   False       False    False  False           False          False
# 7  False   False       False    False  False           False          False
# 8  False   False       False    False  False           False          False
# 9  False   False       False    False  False           False           True
#
#    Turning_Circle Turning_Loop
# 0           False        False
# 1           False        False
# 2           False        False
# 3           False        False
# 4           False        False
# 5           False        False
# 6           False        False
# 7           False        False
# 8           False        False
# 9           False        False
#
# [10 rows x 58 columns]

# %%
print("shape of data is {}".format(traffic_events_data.shape))
print(number_of_file_in_folders)
columns = []
for col in traffic_events_data.columns: 
    columns.append(col)

for folder_index in range(number_of_folders):
    dir = os.path.join(TrafficEvents["path"], TrafficEvents["part_path"], str(folder_index))
    print(dir)
    print("folder_index: {}".format(folder_index))
    if not os.path.exists(dir):
        os.mkdir(dir)

    for file_index in range(number_of_file_in_folders):
        print("file_index: {}".format(file_index))
        base_index = (folder_index *  number_of_records_in_each_file * number_of_file_in_folders)
        start_point_record = base_index + file_index * number_of_records_in_each_file
        end_point_record = base_index + (file_index + 1) * number_of_records_in_each_file
        
        print("start is {} and end is {}".format(start_point_record, end_point_record))
        df = pd.DataFrame(columns=columns)
        for index in range(start_point_record, end_point_record): 
            data = traffic_events_data.iloc[index]
            df = df.append(data, ignore_index=False)
        print(df.shape)
        file_url = dir + "/file_{}.csv".format(file_index)
        df.to_csv (file_url, index = False, header=True)
        print(len(df))
        
print("end")
# Out:
# shape of data is (2046493, 58)
# 411
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/1
# folder_index: 1
# file_index: 0
# start is 205500 and end is 206000
# (500, 58)
# 500
# file_index: 1
# start is 206000 and end is 206500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-76f8f324523d> in <module>
#      22         for index in range(start_point_record, end_point_record):
#      23             data = traffic_events_data.iloc[index]
# ---> 24             df = df.append(data, ignore_index=False)
#      25         print(df.shape)
#      26         file_url = dir + "/file_{}.csv".format(file_index)
#
# ~/python_env/roadConstruction/lib/python3.8/site-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7058                 combined_columns = self.columns.astype(object).append(idx_diff)
#    7059             other = (
# -> 7060                 other.reindex(combined_columns, copy=False)
#    7061                 .to_frame()
#    7062                 .T.infer_objects()
#
# ~/python_env/roadConstruction/lib/python3.8/site-packages/pandas/core/generic.py in infer_objects(self)
#    5915         # native numpy numeric types
#    5916         return self._constructor(
# -> 5917             self._data.convert(
#    5918                 datetime=True, numeric=False, timedelta=True, coerce=False, copy=True
#    5919             )
#
# ~/python_env/roadConstruction/lib/python3.8/site-packages/pandas/core/internals/managers.py in convert(self, **kwargs)
#     583
#     584     def convert(self, **kwargs):
# --> 585         return self.apply("convert", **kwargs)
#     586
#     587     def replace(self, value, **kwargs):
#
# ~/python_env/roadConstruction/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# ~/python_env/roadConstruction/lib/python3.8/site-packages/pandas/core/internals/blocks.py in convert(self, copy, datetime, numeric, timedelta, coerce)
#    2641
#    2642         if self.ndim == 2:
# -> 2643             blocks = self.split_and_operate(None, f, False)
#    2644         else:
#    2645             values = f(None, self.values.ravel(), None)
#
# ~/python_env/roadConstruction/lib/python3.8/site-packages/pandas/core/internals/blocks.py in split_and_operate(self, mask, f, inplace)
#     498                 nv = v if inplace else v.copy()
#     499
# --> 500             block = make_a_block(nv, [ref_loc])
#     501             new_blocks.append(block)
#     502
#
# ~/python_env/roadConstruction/lib/python3.8/site-packages/pandas/core/internals/blocks.py in make_a_block(nv, ref_loc)
#     474                 # a block out of the result.
#     475                 nv = _block_shape(nv, ndim=self.ndim)
# --> 476                 block = self.make_block(values=nv, placement=ref_loc)
#     477             return block
#     478
#
# ~/python_env/roadConstruction/lib/python3.8/site-packages/pandas/core/internals/blocks.py in make_block(self, values, placement)
#     271             placement = self.mgr_locs
#     272
# --> 273         return make_block(values, placement=placement, ndim=self.ndim)
#     274
#     275     def make_block_same_class(self, values, placement=None, ndim=None):
#
# ~/python_env/roadConstruction/lib/python3.8/site-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype)
#    3044     if klass is None:
#    3045         dtype = dtype or values.dtype
# -> 3046         klass = get_block_type(values, dtype)
#    3047
#    3048     elif klass is DatetimeTZBlock and not is_datetime64tz_dtype(values):
#
# ~/python_env/roadConstruction/lib/python3.8/site-packages/pandas/core/internals/blocks.py in get_block_type(values, dtype)
#    3011     elif is_datetime64tz_dtype(values):
#    3012         cls = DatetimeTZBlock
# -> 3013     elif is_interval_dtype(dtype) or is_period_dtype(dtype):
#    3014         cls = ObjectValuesExtensionBlock
#    3015     elif is_extension_array_dtype(values):
#
# ~/python_env/roadConstruction/lib/python3.8/site-packages/pandas/core/dtypes/common.py in is_period_dtype(arr_or_dtype)
#     501     if arr_or_dtype is None:
#     502         return False
# --> 503     return PeriodDtype.is_dtype(arr_or_dtype)
#     504
#     505
#
# ~/python_env/roadConstruction/lib/python3.8/site-packages/pandas/core/dtypes/dtypes.py in is_dtype(cls, dtype)
#     935             else:
#     936                 return False
# --> 937         return super().is_dtype(dtype)
#     938
#     939     @classmethod
#
# KeyboardInterrupt:
