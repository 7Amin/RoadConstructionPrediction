# %%
import pandas as pd
import requests 
import os
import math
from xml.etree import ElementTree
from datetime import datetime

# %%
TrafficEvents = None

OSRM_BASIC_URL = "https://usaeta.bluebitsoft.com/"
BASE_PATH = "/home/amin/CETI/RoadConstruction/TrafficEventData/part/"
    
index_folder = 9
index_start_point_file = 0
index_end_point_file = 393

# %%
def read_data(path):
    data = None
    print("read csv data is started with file {}".format(path))
    data = pd.read_csv(path)
    print("reading is finished length is {} ".format(len(data)))
    return data

def most_frequent(List): 
    occurence_count = Counter(List) 
    return occurence_count.most_common(1)[0][0]

# %%
class Location(object):
    def __init__(self, latitude, longitude):
        self.longitude = longitude
        self.latitude = latitude

# %%
RoadClosed = ['closed due to roadwork', 'closed for bridge', 'road close', 'road block', 
             'road closure']

# %%
LaneClosed = ['lane block', 'lanes block', 'roadway reduce', 'carpool lane', 'lane closure', 'lanes closure'
             'shoulder close', 'shoulder block', 'lane close', 'lanes close']

# %%
out_dir = BASE_PATH + "road_closure/" + str(index_folder)
if not os.path.exists(out_dir):
     os.mkdir(out_dir)

for i in range(index_start_point_file, index_end_point_file):
    print("file id is {}".format(i))
    print("start time is {}".format(datetime.now()))
    path = BASE_PATH + "speeds/speed" + "_" + str(index_folder) +"/" + str(i) + "_file_"+ str(i) + ".csv"
    
    print(path)
    road_closures = []
    lane_closures = []
    traffic_events_data = read_data(path)
    traffic_events_data.head()
    for index, data in traffic_events_data.iterrows():
        road_closure = False
        lane_closure = False
        desc = data["FullDescription"]
        short_desc = data["ShortDescription"]
        if desc and type(desc) == str:
            desc = desc.lower();
        else:
            desc = 'XX'
        
        if short_desc and type(short_desc) == str:
            short_desc = short_desc.lower();
        else:
            short_desc = 'XX'
        
        
#         print(desc)
#         print(short_desc)
        for word in RoadClosed:
            if desc and word in desc:
                road_closure = True
                break
            if short_desc and word in short_desc:
                road_closure = True
                break

        if (not road_closure):
            for word in LaneClosed:
                if desc and word in desc:
                    lane_closure = True
                    break
                if short_desc and word in short_desc:
                    lane_closure = True
                    break
                    
        
        road_closures.append(road_closure)
        lane_closures.append(lane_closure)
#         print("road is {}, and lane is {}".format(road_closure, lane_closure))
    traffic_events_data["road_closure"] = road_closures 
    traffic_events_data["lane_closure"] = lane_closures
    output_file_url = out_dir + "/" + str(i) + "_file_"+ str(i) + ".csv"
    traffic_events_data.to_csv (output_file_url, index = False, header=True)
    
    print(traffic_events_data.columns)
    print("{} done".format(output_file_url))
    print("end time is {}".format(datetime.now()))
# Out:
# file id is 0
# start time is 2020-09-25 18:41:22.095044
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/0_file_0.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/0_file_0.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/0_file_0.csv done
# end time is 2020-09-25 18:41:22.245221
# file id is 1
# start time is 2020-09-25 18:41:22.245269
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/1_file_1.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/1_file_1.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/1_file_1.csv done
# end time is 2020-09-25 18:41:22.397329
# file id is 2
# start time is 2020-09-25 18:41:22.397377
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/2_file_2.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/2_file_2.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/2_file_2.csv done
# end time is 2020-09-25 18:41:22.560908
# file id is 3
# start time is 2020-09-25 18:41:22.560958
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/3_file_3.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/3_file_3.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/3_file_3.csv done
# end time is 2020-09-25 18:41:22.717940
# file id is 4
# start time is 2020-09-25 18:41:22.717988
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/4_file_4.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/4_file_4.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/4_file_4.csv done
# end time is 2020-09-25 18:41:22.872358
# file id is 5
# start time is 2020-09-25 18:41:22.872407
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/5_file_5.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/5_file_5.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/5_file_5.csv done
# end time is 2020-09-25 18:41:23.092654
# file id is 6
# start time is 2020-09-25 18:41:23.092700
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/6_file_6.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/6_file_6.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/6_file_6.csv done
# end time is 2020-09-25 18:41:23.253935
# file id is 7
# start time is 2020-09-25 18:41:23.253983
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/7_file_7.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/7_file_7.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/7_file_7.csv done
# end time is 2020-09-25 18:41:23.407055
# file id is 8
# start time is 2020-09-25 18:41:23.407109
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/8_file_8.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/8_file_8.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/8_file_8.csv done
# end time is 2020-09-25 18:41:23.563627
# file id is 9
# start time is 2020-09-25 18:41:23.563675
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/9_file_9.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/9_file_9.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/9_file_9.csv done
# end time is 2020-09-25 18:41:23.709933
# file id is 10
# start time is 2020-09-25 18:41:23.709982
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/10_file_10.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/10_file_10.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/10_file_10.csv done
# end time is 2020-09-25 18:41:23.860243
# file id is 11
# start time is 2020-09-25 18:41:23.860292
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/11_file_11.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/11_file_11.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/11_file_11.csv done
# end time is 2020-09-25 18:41:24.009826
# file id is 12
# start time is 2020-09-25 18:41:24.009876
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/12_file_12.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/12_file_12.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/12_file_12.csv done
# end time is 2020-09-25 18:41:24.169853
# file id is 13
# start time is 2020-09-25 18:41:24.169901
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/13_file_13.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/13_file_13.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/13_file_13.csv done
# end time is 2020-09-25 18:41:24.319227
# file id is 14
# start time is 2020-09-25 18:41:24.319276
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/14_file_14.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/14_file_14.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/14_file_14.csv done
# end time is 2020-09-25 18:41:24.469559
# file id is 15
# start time is 2020-09-25 18:41:24.469606
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/15_file_15.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/15_file_15.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/15_file_15.csv done
# end time is 2020-09-25 18:41:24.617023
# file id is 16
# start time is 2020-09-25 18:41:24.617072
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/16_file_16.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/16_file_16.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/16_file_16.csv done
# end time is 2020-09-25 18:41:24.768111
# file id is 17
# start time is 2020-09-25 18:41:24.768168
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/17_file_17.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/17_file_17.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/17_file_17.csv done
# end time is 2020-09-25 18:41:24.923991
# file id is 18
# start time is 2020-09-25 18:41:24.924040
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/18_file_18.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/18_file_18.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/18_file_18.csv done
# end time is 2020-09-25 18:41:25.074808
# file id is 19
# start time is 2020-09-25 18:41:25.074856
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/19_file_19.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/19_file_19.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/19_file_19.csv done
# end time is 2020-09-25 18:41:25.222416
# file id is 20
# start time is 2020-09-25 18:41:25.222465
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/20_file_20.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/20_file_20.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/20_file_20.csv done
# end time is 2020-09-25 18:41:25.376684
# file id is 21
# start time is 2020-09-25 18:41:25.376731
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/21_file_21.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/21_file_21.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/21_file_21.csv done
# end time is 2020-09-25 18:41:25.529949
# file id is 22
# start time is 2020-09-25 18:41:25.530000
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/22_file_22.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/22_file_22.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/22_file_22.csv done
# end time is 2020-09-25 18:41:25.682285
# file id is 23
# start time is 2020-09-25 18:41:25.682334
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/23_file_23.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/23_file_23.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/23_file_23.csv done
# end time is 2020-09-25 18:41:25.828635
# file id is 24
# start time is 2020-09-25 18:41:25.828684
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/24_file_24.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/24_file_24.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/24_file_24.csv done
# end time is 2020-09-25 18:41:25.979365
# file id is 25
# start time is 2020-09-25 18:41:25.979413
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/25_file_25.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/25_file_25.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/25_file_25.csv done
# end time is 2020-09-25 18:41:26.127822
# file id is 26
# start time is 2020-09-25 18:41:26.127880
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/26_file_26.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/26_file_26.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/26_file_26.csv done
# end time is 2020-09-25 18:41:26.280487
# file id is 27
# start time is 2020-09-25 18:41:26.280534
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/27_file_27.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/27_file_27.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/27_file_27.csv done
# end time is 2020-09-25 18:41:26.427506
# file id is 28
# start time is 2020-09-25 18:41:26.427555
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/28_file_28.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/28_file_28.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/28_file_28.csv done
# end time is 2020-09-25 18:41:26.579355
# file id is 29
# start time is 2020-09-25 18:41:26.579403
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/29_file_29.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/29_file_29.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
# ...
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/385_file_385.csv done
# end time is 2020-09-25 18:42:16.937955
# file id is 386
# start time is 2020-09-25 18:42:16.938000
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/386_file_386.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/386_file_386.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/386_file_386.csv done
# end time is 2020-09-25 18:42:17.085285
# file id is 387
# start time is 2020-09-25 18:42:17.085333
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/387_file_387.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/387_file_387.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/387_file_387.csv done
# end time is 2020-09-25 18:42:17.244466
# file id is 388
# start time is 2020-09-25 18:42:17.244516
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/388_file_388.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/388_file_388.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/388_file_388.csv done
# end time is 2020-09-25 18:42:17.396448
# file id is 389
# start time is 2020-09-25 18:42:17.396498
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/389_file_389.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/389_file_389.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/389_file_389.csv done
# end time is 2020-09-25 18:42:17.552457
# file id is 390
# start time is 2020-09-25 18:42:17.552508
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/390_file_390.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/390_file_390.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/390_file_390.csv done
# end time is 2020-09-25 18:42:17.702089
# file id is 391
# start time is 2020-09-25 18:42:17.702137
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/391_file_391.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/391_file_391.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/391_file_391.csv done
# end time is 2020-09-25 18:42:17.853693
# file id is 392
# start time is 2020-09-25 18:42:17.853741
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/392_file_392.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/392_file_392.csv
# reading is finished length is 500
# Index(['Id', 'Source', 'Type', 'EventCode', 'Severity', 'StartPoint_Lat',
#        'StartPoint_Lng', 'EndPoint_Lat', 'EndPoint_Lng', 'Distance(mi)',
#        'StartTime', 'EndTime', 'ImpactingRoad', 'DelayFromTypical(mins)',
#        'DelayFromFreeFlow(mins)', 'ShortDescription', 'FullDescription',
#        'AdditionalDescription', 'Number', 'Street', 'Side', 'City', 'County',
#        'State', 'Country', 'ZipCode', 'LocalTimeZone', 'AirportCode',
#        'WeatherTimeStamp', 'Temperature(F)', 'WindChill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'WindDir', 'WindSpeed(mph)',
#        'Precipitation(in)', 'Event', 'Conditions', 'DayLight',
#        'AstronomicalDayLight', 'NauticalDayLight', 'CivilDayLight', 'Amenity',
#        'Bump', 'Crossing', 'Entrance', 'Give_Way', 'Junction', 'Noexit',
#        'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming',
#        'Traffic_Signal', 'Turning_Circle', 'Turning_Loop',
#        'nearst_nodes_of_start_point', 'nearst_nodes_of_end_point',
#        'nearst_nodes_ids_of_start_point', 'nearst_nodes_ids_of_end_point',
#        'type_of_roads', 'avg_speed', 'distance', 'eta', 'road_closure',
#        'lane_closure'],
#       dtype='object')
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/road_closure/9/392_file_392.csv done
# end time is 2020-09-25 18:42:18.002000
# file id is 393
# start time is 2020-09-25 18:42:18.002050
# /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/393_file_393.csv
# read csv data is started with file /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/393_file_393.csv
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-77-e2f0e1fb0d24> in <module>
#      11     road_closures = []
#      12     lane_closures = []
# ---> 13     traffic_events_data = read_data(path)
#      14     traffic_events_data.head()
#      15     for index, data in traffic_events_data.iterrows():
#
# <ipython-input-73-15b13af8a40a> in read_data(path)
#       2     data = None
#       3     print("read csv data is started with file {}".format(path))
# ----> 4     data = pd.read_csv(path)
#       5     print("reading is finished length is {} ".format(len(data)))
#       6     return data
#
# ~/python_env/roadConstruction/lib/python3.8/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/python_env/roadConstruction/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~/python_env/roadConstruction/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~/python_env/roadConstruction/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~/python_env/roadConstruction/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File /home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/393_file_393.csv does not exist: '/home/amin/CETI/RoadConstruction/TrafficEventData/part/speeds/speed_9/393_file_393.csv'

# %%
print("asd")
